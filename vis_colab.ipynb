# %% [markdown]
# <a href="https://colab.research.google.com/github/dercodeKoenig/hft_dqn/blob/main/vis_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/dercodeKoenig/hft_dqn
# Out:
# Cloning into 'hft_dqn'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 106 (delta 13), reused 5 (delta 2), pack-reused 80 (from 1)
# Receiving objects: 100% (106/106), 61.06 MiB | 18.06 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Updating files: 100% (20/20), done.

# %%
# %cd hft_dqn
# Out:
# /content/hft_dqn

# %%
from save_and_load import *
import matplotlib.pyplot as plt

path = "/content/drive/MyDrive/dqn_t1/"


loss_mean = obj_load(path+"loss")
q_mean = obj_load(path+"q")
rewards = obj_load(path+"rewards")

import IPython
IPython.display.clear_output()

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].plot(loss_mean[25:])
axs[0].set_title('Loss Mean')

axs[1].plot(q_mean[25:])
axs[1].set_title('Q Mean')

rewards_sum = [0]
for r in rewards:
    rewards_sum.append(rewards_sum[-1]+r)

#axs[2].plot(rewards)
axs[2].plot(rewards_sum)
axs[2].axhline(0, color='r', linestyle='--')
axs[2].set_title('Rewards')

plt.tight_layout()
plt.show()

# %%
import time
time.sleep(10)
import google
google.colab.runtime.unassign()
